# %%
import logging
from humemai.agent import ExampleAgent

logging.getLogger("humemai").setLevel(logging.WARNING)

# Initialize the Agent
agent = ExampleAgent()

# First conversation with the agent
agent.process_input("Alice met Bob in Paris on May 5th, 2023 during the AI Conference.")
agent.print_memory()

# Clear remaining short-term memories
agent.clear_short_term_memories()
agent.print_memory()

# New conversation with the agent
agent.process_input("Charlie saw Alice in Seoul on June 10th, 2024.")
agent.print_memory()

# Clear remaining short-term memories
agent.clear_short_term_memories()
agent.print_memory()

# More conversations with the agent (10 additional sentences)
sentences = [
    "David attended a workshop in London on September 15th, 2021.",
    "Emma spoke with John at the university library in New York last week.",
    "Sophia collaborated with Michael on a project in San Francisco in March 2022.",
    "Lucas visited his grandmother in Chicago during Christmas of 2019.",
    "Mia and Noah went hiking together in the Rocky Mountains in July.",
    "Liam studied computer science at MIT from 2018 to 2022.",
    "Isabella discussed climate change with experts at a conference in Copenhagen in 2020.",
    "Olivia and Ethan traveled to Japan for a business trip in April 2021.",
    "James met William at a restaurant in Berlin two days ago.",
    "Ava gave a speech on AI at a technology summit in Silicon Valley last month.",
]

# Process each sentence and interact with the memory system
for sentence in sentences:
    agent.process_input(sentence)
    agent.print_memory()
    agent.clear_short_term_memories()

# Print final memory state after all sentences
print("\nFinal memory system state after processing all sentences:")
agent.print_memory()
# Out:
# /home/tk/.virtualenvs/humemai/lib/python3.10/site-packages/torch/cuda/__init__.py:128: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# Entities found: [('Alice', 'PERSON'), ('Bob', 'PERSON'), ('Paris', 'GPE'), ('May 5th, 2023', 'DATE'), ('the AI Conference', 'FAC')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Alice'), rdflib.term.URIRef('https://example.org/meet'), rdflib.term.URIRef('https://example.org/Bob')), (rdflib.term.URIRef('https://example.org/Bob'), rdflib.term.URIRef('https://example.org/meet'), rdflib.term.URIRef('https://example.org/Paris'))]
# Location: Paris
# Time: 2023-05-05T00:00:00
#
# No long-term memories available. Retrieving all memories.
# Moving memory to episodic long-term with emotion: curious, event: Travel
# Moved short-term memory with ID 1 to episodic long-term memory.
# Moving memory to episodic long-term with emotion: excited, event: Meeting
# Moved short-term memory with ID 0 to episodic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Charlie', 'PERSON'), ('Alice', 'PERSON'), ('Seoul', 'GPE'), ('June 10th, 2024', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Charlie'), rdflib.term.URIRef('https://example.org/see'), rdflib.term.URIRef('https://example.org/Alice')), (rdflib.term.URIRef('https://example.org/Alice'), rdflib.term.URIRef('https://example.org/see'), rdflib.term.URIRef('https://example.org/Seoul'))]
# Location: Seoul
# Time: 2024-06-10T00:00:00
#
# Selected trigger node: https://example.org/Alice with 3 hops
# Moving memory to episodic long-term with emotion: happy, event: AI Conference
# Moved short-term memory with ID 5 to episodic long-term memory.
# Moving memory to semantic long-term with strength: 7, derivedFrom: Research
# Moved short-term memory with ID 4 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('David', 'PERSON'), ('London', 'GPE'), ('September 15th, 2021', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/David'), rdflib.term.URIRef('https://example.org/attend'), rdflib.term.URIRef('https://example.org/London'))]
# Location: London
# Time: 2021-09-15T00:00:00
#
# Selected trigger node: https://example.org/Bob with 1 hops
# Moving memory to semantic long-term with strength: 1, derivedFrom: Research
# Moved short-term memory with ID 8 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('John', 'PERSON'), ('New York', 'GPE'), ('last week', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/John'), rdflib.term.URIRef('https://example.org/speak'), rdflib.term.URIRef('https://example.org/New')), (rdflib.term.URIRef('https://example.org/New'), rdflib.term.URIRef('https://example.org/speak'), rdflib.term.URIRef('https://example.org/York'))]
# Location: New York
# Time: None
#
# Selected trigger node: https://example.org/David with 1 hops
# Moving memory to episodic long-term with emotion: excited, event: None
# Moved short-term memory with ID 11 to episodic long-term memory.
# Moving memory to episodic long-term with emotion: excited, event: Meeting
# Moved short-term memory with ID 10 to episodic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Michael', 'PERSON'), ('San Francisco', 'GPE'), ('March 2022', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Michael'), rdflib.term.URIRef('https://example.org/collaborate'), rdflib.term.URIRef('https://example.org/San')), (rdflib.term.URIRef('https://example.org/San'), rdflib.term.URIRef('https://example.org/collaborate'), rdflib.term.URIRef('https://example.org/Francisco'))]
# Location: San Francisco
# Time: 2022-03-03T00:00:00
#
# Selected trigger node: https://example.org/Alice with 3 hops
# Moving memory to episodic long-term with emotion: curious, event: None
# Moved short-term memory with ID 15 to episodic long-term memory.
# Moving memory to semantic long-term with strength: 3, derivedFrom: Research
# Moved short-term memory with ID 14 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Lucas', 'ORG'), ('Chicago', 'GPE'), ('Christmas of 2019', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Lucas'), rdflib.term.URIRef('https://example.org/visit'), rdflib.term.URIRef('https://example.org/Chicago'))]
# Location: Chicago
# Time: None
#
# Selected trigger node: https://example.org/New with 1 hops
# Moving memory to semantic long-term with strength: 1, derivedFrom: None
# Moved short-term memory with ID 18 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Mia', 'PERSON'), ('Noah', 'PERSON'), ('the Rocky Mountains', 'LOC'), ('July', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Mia'), rdflib.term.URIRef('https://example.org/go'), rdflib.term.URIRef('https://example.org/Noah'))]
# Location: None
# Time: 2024-07-03T00:00:00
#
# Selected trigger node: https://example.org/Lucas with 1 hops
# Moving memory to semantic long-term with strength: 10, derivedFrom: Conversation
# Moved short-term memory with ID 20 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Liam', 'PERSON'), ('MIT', 'ORG'), ('2018', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Liam'), rdflib.term.URIRef('https://example.org/study'), rdflib.term.URIRef('https://example.org/MIT'))]
# Location: None
# Time: 2018-10-03T00:00:00
#
# Selected trigger node: https://example.org/Alice with 3 hops
# Moving memory to episodic long-term with emotion: curious, event: Travel
# Moved short-term memory with ID 22 to episodic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Isabella', 'PERSON'), ('Copenhagen', 'ORG'), ('2020', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Isabella'), rdflib.term.URIRef('https://example.org/discuss'), rdflib.term.URIRef('https://example.org/Copenhagen'))]
# Location: None
# Time: 2020-10-03T00:00:00
#
# Selected trigger node: https://example.org/Liam with 2 hops
# Moving memory to semantic long-term with strength: 8, derivedFrom: Observation
# Moved short-term memory with ID 24 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Isabella, https://example.org/discuss, https://example.org/Copenhagen, {'https://humem.ai/ontology/memoryID': '25', 'https://humem.ai/ontology/strength': '8', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('Olivia', 'GPE'), ('Ethan', 'PERSON'), ('Japan', 'GPE'), ('April 2021', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/Olivia'), rdflib.term.URIRef('https://example.org/travel'), rdflib.term.URIRef('https://example.org/Ethan')), (rdflib.term.URIRef('https://example.org/Ethan'), rdflib.term.URIRef('https://example.org/travel'), rdflib.term.URIRef('https://example.org/Japan'))]
# Location: Japan
# Time: 2021-04-03T00:00:00
#
# Selected trigger node: https://example.org/New with 1 hops
# Moving memory to semantic long-term with strength: 4, derivedFrom: None
# Moved short-term memory with ID 27 to semantic long-term memory.
# Moving memory to semantic long-term with strength: 6, derivedFrom: Observation
# Moved short-term memory with ID 26 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Isabella, https://example.org/discuss, https://example.org/Copenhagen, {'https://humem.ai/ontology/memoryID': '25', 'https://humem.ai/ontology/strength': '8', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Ethan, https://example.org/travel, https://example.org/Japan, {'https://humem.ai/ontology/memoryID': '28', 'https://humem.ai/ontology/strength': '4', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Olivia, https://example.org/travel, https://example.org/Ethan, {'https://humem.ai/ontology/memoryID': '29', 'https://humem.ai/ontology/strength': '6', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('James', 'PERSON'), ('William', 'PERSON'), ('Berlin', 'GPE'), ('two days ago', 'DATE')]
# Extracted triples: [(rdflib.term.URIRef('https://example.org/James'), rdflib.term.URIRef('https://example.org/meet'), rdflib.term.URIRef('https://example.org/William')), (rdflib.term.URIRef('https://example.org/William'), rdflib.term.URIRef('https://example.org/meet'), rdflib.term.URIRef('https://example.org/Berlin'))]
# Location: Berlin
# Time: None
#
# Selected trigger node: https://example.org/John with 3 hops
# Moving memory to semantic long-term with strength: 10, derivedFrom: Conversation
# Moved short-term memory with ID 30 to semantic long-term memory.
# Moving memory to semantic long-term with strength: 9, derivedFrom: Research
# Moved short-term memory with ID 31 to semantic long-term memory.
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Isabella, https://example.org/discuss, https://example.org/Copenhagen, {'https://humem.ai/ontology/memoryID': '25', 'https://humem.ai/ontology/strength': '8', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Ethan, https://example.org/travel, https://example.org/Japan, {'https://humem.ai/ontology/memoryID': '28', 'https://humem.ai/ontology/strength': '4', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Olivia, https://example.org/travel, https://example.org/Ethan, {'https://humem.ai/ontology/memoryID': '29', 'https://humem.ai/ontology/strength': '6', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/James, https://example.org/meet, https://example.org/William, {'https://humem.ai/ontology/memoryID': '32', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/William, https://example.org/meet, https://example.org/Berlin, {'https://humem.ai/ontology/memoryID': '33', 'https://humem.ai/ontology/strength': '9', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Entities found: [('AI', 'ORG'), ('Silicon Valley', 'LOC'), ('last month', 'DATE')]
# Extracted triples: []
# Location: None
# Time: None
#
# Selected trigger node: https://example.org/Isabella with 1 hops
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Isabella, https://example.org/discuss, https://example.org/Copenhagen, {'https://humem.ai/ontology/memoryID': '25', 'https://humem.ai/ontology/strength': '8', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Ethan, https://example.org/travel, https://example.org/Japan, {'https://humem.ai/ontology/memoryID': '28', 'https://humem.ai/ontology/strength': '4', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Olivia, https://example.org/travel, https://example.org/Ethan, {'https://humem.ai/ontology/memoryID': '29', 'https://humem.ai/ontology/strength': '6', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/James, https://example.org/meet, https://example.org/William, {'https://humem.ai/ontology/memoryID': '32', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/William, https://example.org/meet, https://example.org/Berlin, {'https://humem.ai/ontology/memoryID': '33', 'https://humem.ai/ontology/strength': '9', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
#
# Final memory system state after processing all sentences:
#
# Memory System:
# [https://example.org/Bob, https://example.org/meet, https://example.org/Paris, {'https://humem.ai/ontology/memoryID': '2', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/meet, https://example.org/Bob, {'https://humem.ai/ontology/memoryID': '3', 'https://humem.ai/ontology/location': 'Paris', 'https://humem.ai/ontology/time': '2023-05-05T00:00:00', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Alice, https://example.org/see, https://example.org/Seoul, {'https://humem.ai/ontology/memoryID': '6', 'https://humem.ai/ontology/location': 'Seoul', 'https://humem.ai/ontology/time': '2024-06-10T00:00:00', 'https://humem.ai/ontology/emotion': 'happy', 'https://humem.ai/ontology/event': 'AI Conference', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Charlie, https://example.org/see, https://example.org/Alice, {'https://humem.ai/ontology/memoryID': '7', 'https://humem.ai/ontology/strength': '7', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/David, https://example.org/attend, https://example.org/London, {'https://humem.ai/ontology/memoryID': '9', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/New, https://example.org/speak, https://example.org/York, {'https://humem.ai/ontology/memoryID': '12', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001871', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/John, https://example.org/speak, https://example.org/New, {'https://humem.ai/ontology/memoryID': '13', 'https://humem.ai/ontology/location': 'New York', 'https://humem.ai/ontology/time': '2024-10-03T20:49:35.001770', 'https://humem.ai/ontology/emotion': 'excited', 'https://humem.ai/ontology/event': 'Meeting', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/San, https://example.org/collaborate, https://example.org/Francisco, {'https://humem.ai/ontology/memoryID': '16', 'https://humem.ai/ontology/location': 'San Francisco', 'https://humem.ai/ontology/time': '2022-03-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Michael, https://example.org/collaborate, https://example.org/San, {'https://humem.ai/ontology/memoryID': '17', 'https://humem.ai/ontology/strength': '3', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Lucas, https://example.org/visit, https://example.org/Chicago, {'https://humem.ai/ontology/memoryID': '19', 'https://humem.ai/ontology/strength': '1', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Mia, https://example.org/go, https://example.org/Noah, {'https://humem.ai/ontology/memoryID': '21', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Liam, https://example.org/study, https://example.org/MIT, {'https://humem.ai/ontology/memoryID': '23', 'https://humem.ai/ontology/location': 'None', 'https://humem.ai/ontology/time': '2018-10-03T00:00:00', 'https://humem.ai/ontology/emotion': 'curious', 'https://humem.ai/ontology/event': 'Travel', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Isabella, https://example.org/discuss, https://example.org/Copenhagen, {'https://humem.ai/ontology/memoryID': '25', 'https://humem.ai/ontology/strength': '8', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Ethan, https://example.org/travel, https://example.org/Japan, {'https://humem.ai/ontology/memoryID': '28', 'https://humem.ai/ontology/strength': '4', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/Olivia, https://example.org/travel, https://example.org/Ethan, {'https://humem.ai/ontology/memoryID': '29', 'https://humem.ai/ontology/strength': '6', 'https://humem.ai/ontology/derivedFrom': 'Observation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/James, https://example.org/meet, https://example.org/William, {'https://humem.ai/ontology/memoryID': '32', 'https://humem.ai/ontology/strength': '10', 'https://humem.ai/ontology/derivedFrom': 'Conversation', 'https://humem.ai/ontology/recalled': '0'}]
# [https://example.org/William, https://example.org/meet, https://example.org/Berlin, {'https://humem.ai/ontology/memoryID': '33', 'https://humem.ai/ontology/strength': '9', 'https://humem.ai/ontology/derivedFrom': 'Research', 'https://humem.ai/ontology/recalled': '0'}]
